# %% [markdown]
# # "[ML] Decision Tree"
# > "Salary Forecasting을 위한 전처리 및 모델링"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [Decision Tree]
# - author: 도형준

# %% [markdown]
# ![header](https://capsule-render.vercel.app/api?type=waving&color=auto&height=200&section=header&text=Decision%Tree&fontSize=50&animation=fadeIn&fontAlignY=30&desc=2022/11/10&descAlignY=51&descAlign=62)

# %%
# https://www.kaggle.com/datasets/ayessa/salary-prediction-classification
# https://raw.githubusercontent.com/bigdata-young/bigdata_16th/main/data/salary.csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 불러오기

# %%
file_url = 'https://raw.githubusercontent.com/bigdata-young/bigdata_16th/main/data/salary.csv'
df = pd.read_csv(file_url, skipinitialspace=True)

# %%
# df.head()
df.tail()
# Out:
#        age     workclass   education  education-num      marital-status  \
# 48837   27       Private  Assoc-acdm             12  Married-civ-spouse
# 48838   40       Private     HS-grad              9  Married-civ-spouse
# 48839   58       Private     HS-grad              9             Widowed
# 48840   22       Private     HS-grad              9       Never-married
# 48841   52  Self-emp-inc     HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country  class
# 48837             0              38  United-States  <=50K
# 48838             0              40  United-States   >50K
# 48839             0              40  United-States  <=50K
# 48840             0              20  United-States  <=50K
# 48841             0              40  United-States   >50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      46033 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  47985 non-null  object
#  13  class           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         2799
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# class                0
# dtype: int64

# %%
# [연속형 변수]
# age : 연령
# education-num : 교육년수
# capital-gain : 자산 증가량
# capital-loss : 자산 감소량
# hours-per-week : 주당 노동 시간
df.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  48842.000000   48842.000000  48842.000000  48842.000000    48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314       40.422382
# std       13.710510       2.570973   7452.019058    403.004552       12.391444
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
# [범주형 변수]
# workclass : 고용 형태
# education : 학력
# marital-status : 결혼 상태
# occupation : 직업
# relationship : 가족관계
# race : 인종
# sex : 성별
# native-country : 출신국가
# class : 연봉 범위
df.describe(include=['O'])
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      46043     48842               48842           46033        48842
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race    sex native-country  class
# count   48842  48842          47985  48842
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
df.describe(include='all')
# Out:
#                  age workclass education  education-num      marital-status  \
# count   48842.000000     46043     48842   48842.000000               48842
# unique           NaN         8        16            NaN                   7
# top              NaN   Private   HS-grad            NaN  Married-civ-spouse
# freq             NaN     33906     15784            NaN               22379
# mean       38.643585       NaN       NaN      10.078089                 NaN
# std        13.710510       NaN       NaN       2.570973                 NaN
# min        17.000000       NaN       NaN       1.000000                 NaN
# 25%        28.000000       NaN       NaN       9.000000                 NaN
# 50%        37.000000       NaN       NaN      10.000000                 NaN
# 75%        48.000000       NaN       NaN      12.000000                 NaN
# max        90.000000       NaN       NaN      16.000000                 NaN
#
#             occupation relationship   race    sex  capital-gain  capital-loss  \
# count            46033        48842  48842  48842  48842.000000  48842.000000
# unique              14            6      5      2           NaN           NaN
# top     Prof-specialty      Husband  White   Male           NaN           NaN
# freq              6172        19716  41762  32650           NaN           NaN
# mean               NaN          NaN    NaN    NaN   1079.067626     87.502314
# std                NaN          NaN    NaN    NaN   7452.019058    403.004552
# min                NaN          NaN    NaN    NaN      0.000000      0.000000
# 25%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 50%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 75%                NaN          NaN    NaN    NaN      0.000000      0.000000
# max                NaN          NaN    NaN    NaN  99999.000000   4356.000000
#
#         hours-per-week native-country  class
# count     48842.000000          47985  48842
# unique             NaN             41      2
# top                NaN  United-States  <=50K
# freq               NaN          43832  37155
# mean         40.422382            NaN    NaN
# std          12.391444            NaN    NaN
# min           1.000000            NaN    NaN
# 25%          40.000000            NaN    NaN
# 50%          40.000000            NaN    NaN
# 75%          45.000000            NaN    NaN
# max          99.000000            NaN    NaN

# %%
import plotly.express as px
fig = px.imshow(df.corr(),text_auto=True, color_continuous_scale='RdBu_r',title='상관관계 히트맵', aspect='auto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1b5b7ae1-95c0-45d8-97f2-49585423458d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b5b7ae1-95c0-45d8-97f2-49585423458d")) {                    Plotly.newPlot(                        "1b5b7ae1-95c0-45d8-97f2-49585423458d",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["age","education-num","capital-gain","capital-loss","hours-per-week"],"y":["age","education-num","capital-gain","capital-loss","hours-per-week"],"z":[[1.0,0.030940375874514196,0.07722902236438149,0.056943826105612515,0.07155833852698332],[0.030940375874514196,1.0,0.12514645910572106,0.08097193774847265,0.14368890939248008],[0.07722902236438149,0.12514645910572106,1.0,-0.0314407706474634,0.08215727805587845],[0.056943826105612515,0.08097193774847265,-0.0314407706474634,1.0,0.05446721609518717],[0.07155833852698332,0.14368890939248008,0.08215727805587845,0.05446721609518717,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %% [markdown]
# ![header](https://capsule-render.vercel.app/api?type=waving&color=auto&height=200&section=header&text=전처리&fontSize=50&animation=fadeIn&fontAlignY=30&desc=&descAlignY=51&descAlign=62)
#
# - 범주형변수(drop or 연속형 변수 or dummies or 대체?)<br>
# - 결측치
# - -> 스케일링 -> 아웃라이어 신경X. 결정트리이기 때문
# <br>
# 2-1. eductaion: eductaion-num drop<br>
# 2-2. occupation: 이미 묶여있고, 중요할 것이라 판단 => dummies<br>
# 2-3. native-country: 출신국가들인데 어차피 결정트리이기에<br>

# %% [markdown]
# # 전처리

# %%
df['class']
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: class, Length: 48842, dtype: object

# %%
df['class'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: class, dtype: int64

# %%
df['class'] = df['class'].map({'<=50K': 0, '>50K': 1})
df['class']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: class, Length: 48842, dtype: int64

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
obj_list = []
for c in df.columns:
  if df[c].dtype == 'object':
    #print(c,df[c].dtype)
    obj_list.append(c)
obj_list
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country']

# %%
# List Comprehension
obj_list2 = [c for c in df.columns if df[c].dtype=='object']
obj_list2
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country']

# %%
for o in obj_list:
    print(o, df[o].nunique())
# Out:
# workclass 8
# education 16
# marital-status 7
# occupation 14
# relationship 6
# race 5
# sex 2
# native-country 41

# %%
# education으로 기준으로 묶기에는 너무 많다라는 판단
for o in obj_list:
    if df[o].nunique() > 10:
        print(o, df[o].nunique())
# Out:
# education 16
# occupation 14
# native-country 41

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
# 'education'과 비슷한 컬럼인 'education-num'확인
df['education-num']
# Out:
# 0         7
# 1         9
# 2        12
# 3        10
# 4        10
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: education-num, Length: 48842, dtype: int64

# %%
df[df['education-num']==1]['education']
# Out:
# 779      Preschool
# 818      Preschool
# 1029     Preschool
# 1059     Preschool
# 1489     Preschool
#            ...
# 48079    Preschool
# 48316    Preschool
# 48505    Preschool
# 48640    Preschool
# 48713    Preschool
# Name: education, Length: 83, dtype: object

# %%
for n in range(1,17): #1~16
  #  print(df[df['education-num']==n]['education'])
  print(f"**{n}**", df[df['education-num'] == n]['education'].unique())
# 2개의 데이터는 일치한다.
# Out:
# **1** ['Preschool']
# **2** ['1st-4th']
# **3** ['5th-6th']
# **4** ['7th-8th']
# **5** ['9th']
# **6** ['10th']
# **7** ['11th']
# **8** ['12th']
# **9** ['HS-grad']
# **10** ['Some-college']
# **11** ['Assoc-voc']
# **12** ['Assoc-acdm']
# **13** ['Bachelors']
# **14** ['Masters']
# **15** ['Prof-school']
# **16** ['Doctorate']

# %%
df.drop('education',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education-num   48842 non-null  int64
#  3   marital-status  48842 non-null  object
#  4   occupation      46033 non-null  object
#  5   relationship    48842 non-null  object
#  6   race            48842 non-null  object
#  7   sex             48842 non-null  object
#  8   capital-gain    48842 non-null  int64
#  9   capital-loss    48842 non-null  int64
#  10  hours-per-week  48842 non-null  int64
#  11  native-country  47985 non-null  object
#  12  class           48842 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 4.8+ MB

# %%
# 데이터가 이미 묶여있음
# 직업이라는 데이터 특성상 연봉이 큰 영향을 줄 것이라 예상
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts() # 미국이 가장 많다. 나머지 더미화?
# 1. 미국 vs 기타: 0/1
# 2. 대륙별, 언어권별 => 추가적인 기준을 만들어서 더미변수화 한다.
# 3. 다 1,2,3,4
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Laos                             23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
# gropuby(묶고 싶은 열 이름) [특정한 열 이름].적용하고자하는 그룹함수() -> mean()
# df.groupby('native-country')['class'].mean()
df.groupby('native-country')['class'].mean().sort_values(ascending=False)
# Out:
# native-country
# France                        0.421053
# India                         0.410596
# Taiwan                        0.400000
# Iran                          0.372881
# England                       0.370079
# Greece                        0.367347
# Yugoslavia                    0.347826
# Japan                         0.347826
# Canada                        0.346154
# Italy                         0.323810
# Cambodia                      0.321429
# Hungary                       0.315789
# Ireland                       0.297297
# China                         0.295082
# Philippines                   0.288136
# Germany                       0.281553
# Hong                          0.266667
# Cuba                          0.246377
# United-States                 0.243977
# Poland                        0.195402
# Portugal                      0.179104
# South                         0.173913
# Thailand                      0.166667
# Scotland                      0.142857
# Jamaica                       0.141509
# Ecuador                       0.133333
# Haiti                         0.120000
# Puerto-Rico                   0.108696
# Honduras                      0.100000
# Peru                          0.086957
# Laos                          0.086957
# Vietnam                       0.081395
# Trinadad&Tobago               0.074074
# El-Salvador                   0.070968
# Nicaragua                     0.061224
# Mexico                        0.049422
# Dominican-Republic            0.048544
# Columbia                      0.047059
# Outlying-US(Guam-USVI-etc)    0.043478
# Guatemala                     0.034091
# Holand-Netherlands            0.000000
# Name: class, dtype: float64

# %%
# country_group 나라별 고연봉자 비율을 원래 DF에 합치고 싶음
# 나라별 -> 나라이름 -> index -> 
country_group = df.groupby('native-country').mean()['class']
country_group
# Out:
# native-country
# Cambodia                      0.321429
# Canada                        0.346154
# China                         0.295082
# Columbia                      0.047059
# Cuba                          0.246377
# Dominican-Republic            0.048544
# Ecuador                       0.133333
# El-Salvador                   0.070968
# England                       0.370079
# France                        0.421053
# Germany                       0.281553
# Greece                        0.367347
# Guatemala                     0.034091
# Haiti                         0.120000
# Holand-Netherlands            0.000000
# Honduras                      0.100000
# Hong                          0.266667
# Hungary                       0.315789
# India                         0.410596
# Iran                          0.372881
# Ireland                       0.297297
# Italy                         0.323810
# Jamaica                       0.141509
# Japan                         0.347826
# Laos                          0.086957
# Mexico                        0.049422
# Nicaragua                     0.061224
# Outlying-US(Guam-USVI-etc)    0.043478
# Peru                          0.086957
# Philippines                   0.288136
# Poland                        0.195402
# Portugal                      0.179104
# Puerto-Rico                   0.108696
# Scotland                      0.142857
# South                         0.173913
# Taiwan                        0.400000
# Thailand                      0.166667
# Trinadad&Tobago               0.074074
# United-States                 0.243977
# Vietnam                       0.081395
# Yugoslavia                    0.347826
# Name: class, dtype: float64

# %%
country_group = country_group.reset_index() # merge하기 위해 key가 필요해, index를 통해 추출 + DF화
country_group
# Out:
#                 native-country     class
# 0                     Cambodia  0.321429
# 1                       Canada  0.346154
# 2                        China  0.295082
# 3                     Columbia  0.047059
# 4                         Cuba  0.246377
# 5           Dominican-Republic  0.048544
# 6                      Ecuador  0.133333
# 7                  El-Salvador  0.070968
# 8                      England  0.370079
# 9                       France  0.421053
# 10                     Germany  0.281553
# 11                      Greece  0.367347
# 12                   Guatemala  0.034091
# 13                       Haiti  0.120000
# 14          Holand-Netherlands  0.000000
# 15                    Honduras  0.100000
# 16                        Hong  0.266667
# 17                     Hungary  0.315789
# 18                       India  0.410596
# 19                        Iran  0.372881
# 20                     Ireland  0.297297
# 21                       Italy  0.323810
# 22                     Jamaica  0.141509
# 23                       Japan  0.347826
# 24                        Laos  0.086957
# 25                      Mexico  0.049422
# 26                   Nicaragua  0.061224
# 27  Outlying-US(Guam-USVI-etc)  0.043478
# 28                        Peru  0.086957
# 29                 Philippines  0.288136
# 30                      Poland  0.195402
# 31                    Portugal  0.179104
# 32                 Puerto-Rico  0.108696
# 33                    Scotland  0.142857
# 34                       South  0.173913
# 35                      Taiwan  0.400000
# 36                    Thailand  0.166667
# 37             Trinadad&Tobago  0.074074
# 38               United-States  0.243977
# 39                     Vietnam  0.081395
# 40                  Yugoslavia  0.347826

# %%
# A.merge(B) A 왼쪽, B 오른쪽
# index가 기본인데/ 아니면 on으로 열(컬럼)을 지정해줘야 함
# native-country -> 결측치가 존재함...

# A 부분에 결측치가 존재함
# A를 모두 보존하는 방향으로 진행 => B가 없어도 됨 => how ='left'

df2 = df.merge(country_group,on='native-country',how='left')

# %%
df2.tail()
# Out:
#        age     workclass  education-num      marital-status  \
# 48837   27       Private             12  Married-civ-spouse
# 48838   40       Private              9  Married-civ-spouse
# 48839   58       Private              9             Widowed
# 48840   22       Private              9       Never-married
# 48841   52  Self-emp-inc              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country  class_x   class_y
# 48837             0              38  United-States        0  0.243977
# 48838             0              40  United-States        1  0.243977
# 48839             0              40  United-States        0  0.243977
# 48840             0              20  United-States        0  0.243977
# 48841             0              40  United-States        1  0.243977

# %%
df2.isnull().sum()
# Out:
# age                  0
# workclass         2799
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# class_x              0
# class_y            857
# dtype: int64

# %% [markdown]
# # 현재 진행상황
# - 범주형변수(drop or 연속형 변수 or dummies or 대체?)<br>
# - 결측치
# - -> 스케일링 -> 아웃라이어 신경X. 결정트리이기 때문
# <br>
# 2-1. eductaion: eductaion-num drop<br>
# 2-2. occupation: 이미 묶여있고, 중요할 것이라 판단 => dummies<br>
# 2-3. native-country: 출신국가들인데 어차피 결정트리이기에<br>

# %%
# df['country_class_mean'] = df.groupby('native-country')['class'].transform('mean')
# class x, class y
#df.drop('native-country', axis=1, inplace=True)
#df

# %% [markdown]
# ![header](https://capsule-render.vercel.app/api?type=waving&color=auto&height=200&section=header&text=결측치%20처리%20/%20더미%20변수화&fontSize=50&animation=fadeIn&fontAlignY=30&desc=&descAlignY=51&descAlign=62)

# %% [markdown]
# # 결측치 처리 / 더미 변수화

# %%
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.057307
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# native-country    0.017546
# class             0.000000
# dtype: float64

# %%
#@title 임의값 넣어주기
df['native-country'].fillna(-99, inplace=True)
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.057307
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# native-country    0.000000
# class             0.000000
# dtype: float64

# %%
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.057307
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# native-country    0.000000
# class             0.000000
# dtype: float64

# %%
df['workclass'].fillna('Private', inplace=True)
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.000000
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# native-country    0.000000
# class             0.000000
# dtype: float64

# %%
df['occupation'].fillna('Unknown', inplace=True)
df.isna().mean()
# Out:
# age               0.0
# workclass         0.0
# education-num     0.0
# marital-status    0.0
# occupation        0.0
# relationship      0.0
# race              0.0
# sex               0.0
# capital-gain      0.0
# capital-loss      0.0
# hours-per-week    0.0
# native-country    0.0
# class             0.0
# dtype: float64

# %%
# 아직 범주형이 남아 있음
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   education-num   48842 non-null  int64
#  3   marital-status  48842 non-null  object
#  4   occupation      48842 non-null  object
#  5   relationship    48842 non-null  object
#  6   race            48842 non-null  object
#  7   sex             48842 non-null  object
#  8   capital-gain    48842 non-null  int64
#  9   capital-loss    48842 non-null  int64
#  10  hours-per-week  48842 non-null  int64
#  11  native-country  48842 non-null  object
#  12  class           48842 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 4.8+ MB

# %%
df2 = pd.get_dummies(df, drop_first=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 84 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        48842 non-null  int64
#  1   education-num                              48842 non-null  int64
#  2   capital-gain                               48842 non-null  int64
#  3   capital-loss                               48842 non-null  int64
#  4   hours-per-week                             48842 non-null  int64
#  5   class                                      48842 non-null  int64
#  6   workclass_Local-gov                        48842 non-null  uint8
#  7   workclass_Never-worked                     48842 non-null  uint8
#  8   workclass_Private                          48842 non-null  uint8
#  9   workclass_Self-emp-inc                     48842 non-null  uint8
#  10  workclass_Self-emp-not-inc                 48842 non-null  uint8
#  11  workclass_State-gov                        48842 non-null  uint8
#  12  workclass_Without-pay                      48842 non-null  uint8
#  13  marital-status_Married-AF-spouse           48842 non-null  uint8
#  14  marital-status_Married-civ-spouse          48842 non-null  uint8
#  15  marital-status_Married-spouse-absent       48842 non-null  uint8
#  16  marital-status_Never-married               48842 non-null  uint8
#  17  marital-status_Separated                   48842 non-null  uint8
#  18  marital-status_Widowed                     48842 non-null  uint8
#  19  occupation_Armed-Forces                    48842 non-null  uint8
#  20  occupation_Craft-repair                    48842 non-null  uint8
#  21  occupation_Exec-managerial                 48842 non-null  uint8
#  22  occupation_Farming-fishing                 48842 non-null  uint8
#  23  occupation_Handlers-cleaners               48842 non-null  uint8
#  24  occupation_Machine-op-inspct               48842 non-null  uint8
#  25  occupation_Other-service                   48842 non-null  uint8
#  26  occupation_Priv-house-serv                 48842 non-null  uint8
#  27  occupation_Prof-specialty                  48842 non-null  uint8
#  28  occupation_Protective-serv                 48842 non-null  uint8
#  29  occupation_Sales                           48842 non-null  uint8
#  30  occupation_Tech-support                    48842 non-null  uint8
#  31  occupation_Transport-moving                48842 non-null  uint8
#  32  occupation_Unknown                         48842 non-null  uint8
#  33  relationship_Not-in-family                 48842 non-null  uint8
#  34  relationship_Other-relative                48842 non-null  uint8
#  35  relationship_Own-child                     48842 non-null  uint8
#  36  relationship_Unmarried                     48842 non-null  uint8
#  37  relationship_Wife                          48842 non-null  uint8
#  38  race_Asian-Pac-Islander                    48842 non-null  uint8
#  39  race_Black                                 48842 non-null  uint8
#  40  race_Other                                 48842 non-null  uint8
#  41  race_White                                 48842 non-null  uint8
#  42  sex_Male                                   48842 non-null  uint8
#  43  native-country_Cambodia                    48842 non-null  uint8
#  44  native-country_Canada                      48842 non-null  uint8
#  45  native-country_China                       48842 non-null  uint8
#  46  native-country_Columbia                    48842 non-null  uint8
#  47  native-country_Cuba                        48842 non-null  uint8
#  48  native-country_Dominican-Republic          48842 non-null  uint8
#  49  native-country_Ecuador                     48842 non-null  uint8
#  50  native-country_El-Salvador                 48842 non-null  uint8
#  51  native-country_England                     48842 non-null  uint8
#  52  native-country_France                      48842 non-null  uint8
#  53  native-country_Germany                     48842 non-null  uint8
#  54  native-country_Greece                      48842 non-null  uint8
#  55  native-country_Guatemala                   48842 non-null  uint8
#  56  native-country_Haiti                       48842 non-null  uint8
#  57  native-country_Holand-Netherlands          48842 non-null  uint8
#  58  native-country_Honduras                    48842 non-null  uint8
#  59  native-country_Hong                        48842 non-null  uint8
#  60  native-country_Hungary                     48842 non-null  uint8
#  61  native-country_India                       48842 non-null  uint8
#  62  native-country_Iran                        48842 non-null  uint8
#  63  native-country_Ireland                     48842 non-null  uint8
#  64  native-country_Italy                       48842 non-null  uint8
#  65  native-country_Jamaica                     48842 non-null  uint8
#  66  native-country_Japan                       48842 non-null  uint8
#  67  native-country_Laos                        48842 non-null  uint8
#  68  native-country_Mexico                      48842 non-null  uint8
#  69  native-country_Nicaragua                   48842 non-null  uint8
#  70  native-country_Outlying-US(Guam-USVI-etc)  48842 non-null  uint8
#  71  native-country_Peru                        48842 non-null  uint8
#  72  native-country_Philippines                 48842 non-null  uint8
#  73  native-country_Poland                      48842 non-null  uint8
#  74  native-country_Portugal                    48842 non-null  uint8
#  75  native-country_Puerto-Rico                 48842 non-null  uint8
#  76  native-country_Scotland                    48842 non-null  uint8
#  77  native-country_South                       48842 non-null  uint8
#  78  native-country_Taiwan                      48842 non-null  uint8
#  79  native-country_Thailand                    48842 non-null  uint8
#  80  native-country_Trinadad&Tobago             48842 non-null  uint8
#  81  native-country_United-States               48842 non-null  uint8
#  82  native-country_Vietnam                     48842 non-null  uint8
#  83  native-country_Yugoslavia                  48842 non-null  uint8
# dtypes: int64(6), uint8(78)
# memory usage: 5.9 MB

# %% [markdown]
# ![header](https://capsule-render.vercel.app/api?type=waving&color=auto&height=200&section=header&text=모델링/평가&fontSize=50&animation=fadeIn&fontAlignY=30&desc=&descAlignY=51&descAlign=62)

# %% [markdown]
# # 모델링/평가

# %%
from sklearn.model_selection import train_test_split
X = df2.drop('class', axis=1)
y = df2['class']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=100
)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=100)
model.fit(X_train,y_train)
pred = model.predict(X_test)

# %%
pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.8163996519424681
